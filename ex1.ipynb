# %%
COUNT = 200
START = 1.0
END = 2

for i in range(COUNT):
    x = START + i*((END-START)/COUNT)
    f = (x**3 -x -1)
    if abs(f-0.0) < 0.01 :
        print("방정식의 해는 ", x)
# Out:
# 방정식의 해는  1.325

# %%
import matplotlib.pyplot #as plt
import numpy as np

x = np.linspace(0, 3, 200)
y = x**3 -x -1 #np.sin(x)
matplotlib.pyplot.plot(x, y)
matplotlib.pyplot.title("Sine Curve")
matplotlib.pyplot.xlabel("x-axis")
matplotlib.pyplot.ylabel("y-axis")
matplotlib.pyplot.grid(True)
matplotlib.pyplot.show()
# print(x)
# print(y)

# %%
import turtle
t = turtle.Turtle()
t.shape("turtle")
t1 = turtle.Turtle()
t1.shape("circle")
t1.fillcolor('violet')
#s = input("몇각형을 원하시나요?:")
#n=int(s)

def draw_rect():
    for i in range(4):
        t.forward(100)
        t.left(90)


draw_rect()

turtle.mainloop()
turtle.bye()

# %%
import turtle
t = turtle

t.shape("turtle")
t1 = turtle

t1.shape("circle")

for i in range(4):
        t.forward(100)
        t.left(90)

for i in range(4):
        t1.forward(100)
        t1.left(90)        

turtle.mainloop()
turtle.bye()
